# %% [markdown]
# <a href="https://colab.research.google.com/github/dtrieu9/test-repository/blob/main/pickle_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import joblib

tree_reg = joblib.load("tree_reg.pkl")

# %%
tree_reg.feature_importances_
# Out:
# array([6.71222055e-02, 5.49604110e-02, 4.12507868e-02, 1.25998899e-02,
#        1.28778939e-02, 1.09423444e-02, 1.19254755e-02, 4.72338831e-01,
#        2.78859741e-02, 1.22668551e-01, 2.23238760e-02, 8.98187992e-04,
#        1.40283874e-01, 0.00000000e+00, 4.70009150e-04, 1.45168987e-03])
