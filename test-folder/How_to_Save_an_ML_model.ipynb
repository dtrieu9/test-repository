# %% [markdown]
# <a href="https://colab.research.google.com/github/dtrieu9/test-repository/blob/main/How_to_Save_an_ML_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to save

import joblib

joblib.dump(my_model, "my_model.pkl")

# %%
# to load elsewhere

import joblib

my_model_loaded = joblib.load("my_model.pkl")
